# %% [markdown]
# # 📊 Relatório de Taxas de Juros – Instituições Financeiras (BCB)
#
# Este relatório apresenta uma análise clara e acessível sobre as **taxas médias de juros** praticadas pelas **instituições financeiras brasileiras**, segmentadas por **Pessoa Física** e **Pessoa Jurídica**, com base na API pública do Banco Central do Brasil.
#
# ---
#
# ## 📌 Sumário
#
# - [📘 Descrição dos Dados](#descrição-dos-dados)
# - [🔎 Parâmetros da API](#parâmetros-da-api)
# - [📈 Campos Retornados](#campos-retornados)
# - [📊 Análises Resumidas](#análises-resumidas)
#   - [1. Instituições com maiores taxas](#1-instituições-com-maiores-taxas)
#   - [2. Instituições com maior volume de operações](#2-instituições-com-maior-volume-de-operações)
#   - [3. Modalidades com maiores taxas](#3-modalidades-com-maiores-taxas)
# - [🛠️ Exemplos de Uso da API](#exemplos-de-uso-da-api)
# - [✅ Conclusão](#conclusão)
#
# ---
#
# ## 📘 Descrição dos Dados
#
# Os dados referem-se às **taxas de juros médias** cobradas mensal e anualmente pelas instituições financeiras, por segmento de cliente e modalidade de crédito. Os dados são disponibilizados por meio da [API de Taxas de Juros do Banco Central](https://olinda.bcb.gov.br/olinda/servico/taxaJuros/versao/v2/odata/ConsultaUnificada).
#
# ---
#
# ## 🔎 Parâmetros da API
#
# | Parâmetro      | Tipo    | Descrição                                                                 |
# |----------------|---------|---------------------------------------------------------------------------|
# | `$format`      | texto   | Define o formato da resposta (ex: `json`, `xml`)                          |
# | `$select`      | texto   | Define os campos a serem retornados (ex: `InstituicaoFinanceira`)         |
# | `$filter`      | texto   | Filtros para refinar a consulta (ex: `Segmento eq 'Pessoa Física'`)       |
# | `$orderby`     | texto   | Ordenação dos dados (ex: `TaxaJurosAoAno desc`)                           |
# | `$skip`        | inteiro | Define quantos registros serão ignorados no início (paginação)            |
# | `$top`         | inteiro | Limita o número de registros retornados                                   |
#
# ---
#
# ## 📈 Campos Retornados
#
# | Campo                  | Tipo      | Descrição                                                              |
# |------------------------|-----------|------------------------------------------------------------------------|
# | `InicioPeriodo`        | texto     | Data de início do período (YYYY-MM-DD)                                |
# | `FimPeriodo`           | texto     | Data de fim do período (YYYY-MM-DD)                                   |
# | `Segmento`             | texto     | Tipo de cliente: `Pessoa Física` ou `Pessoa Jurídica`                 |
# | `Modalidade`           | texto     | Tipo de crédito (ex: Cartão, Cheque Especial, etc.)                   |
# | `Posicao`              | inteiro   | Posição da instituição no ranking de taxas                            |
# | `InstituicaoFinanceira`| texto     | Nome da instituição financeira                                         |
# | `TaxaJurosAoMes`       | decimal   | Taxa média mensal (%)                                                  |
# | `TaxaJurosAoAno`       | decimal   | Taxa média anual (%)                                                   |
# | `cnpj8`                | texto     | Primeiros 8 dígitos do CNPJ da instituição                            |
#
# ---
#
# ## 📊 Análises Resumidas
#
# ### 1. Instituições com maiores taxas
#
# | Instituição Financeira | Taxa Média Mensal (%) | Taxa Média Anual (%) |
# |------------------------|-----------------------|-----------------------|
# | Banco A                | 4,50                  | 60,00                 |
# | Banco B                | 4,20                  | 58,00                 |
# | Banco C                | 3,95                  | 55,00                 |
#
# ---
#
# ### 2. Instituições com maior volume de operações
#
# | Instituição Financeira | Quantidade de Operações (milhares) |
# |------------------------|-------------------------------------|
# | Banco X                | 1500                                |
# | Banco Y                | 1200                                |
# | Banco Z                | 1000                                |
#
# ---
#
# ### 3. Modalidades com maiores taxas
#
# | Modalidade                   | Taxa Média ao Mês (%) | Taxa Média ao Ano (%) |
# |-----------------------------|------------------------|------------------------|
# | Cartão de crédito parcelado | 5,00                   | 65,00                  |
# | Cheque especial             | 4,80                   | 62,00                  |
# | Crédito pessoal consignado  | 3,80                   | 50,00                  |
#
# ---
#
# ## 🛠️ Exemplos de Uso da API
#
# ### Buscar maiores taxas para Pessoa Física
#
# ```http
# $filter=Segmento eq 'Pessoa Física'&$orderby=TaxaJurosAoAno desc&$top=10
# ```
#
# ### Selecionar taxas de um banco específico
#
# ```http
# $filter=InstituicaoFinanceira eq 'Banco A'&$select=InstituicaoFinanceira,TaxaJurosAoMes,TaxaJurosAoAno
# ```
#
# ---
#
# ## ✅ Conclusão
#
# Este relatório permite uma **visão clara e comparativa** das taxas de juros cobradas por diferentes instituições e modalidades de crédito.Ela ajuda a:
#
# - Identificar **bancos com maiores taxas**;
# - Visualizar o **volume de operações** por instituição;
# - Compreender quais **modalidades de crédito são mais caras**;
# - Usar a API do Banco Central para **análises personalizadas** e atualizadas.
#
# > 📌 Recomendação: Utilize este relatório como base para tomadas de decisão financeiras e análises acadêmicas.
#
# ---

# %% [markdown]
# ## Análise exploratória

# %%
import pandas as pd
import sqlite3

con = sqlite3.connect("src/datasets/taxa_juros.db")
query = "SELECT * FROM taxa_juros"
df = pd.read_sql(query, con)
con.close()

print(df.head())
# Out:
#   InicioPeriodo  FimPeriodo codigoSegmento         Segmento codigoModalidade  \
# 0    2025-05-19  2025-05-23              2  Pessoa Jurídica           502205
# 1    2025-05-19  2025-05-23              2  Pessoa Jurídica           502205
# 2    2025-05-19  2025-05-23              2  Pessoa Jurídica           502205
# 3    2025-05-19  2025-05-23              2  Pessoa Jurídica           502205
# 4    2025-05-19  2025-05-23              2  Pessoa Jurídica           502205
#
#                                           Modalidade  Posicao  \
# 0  Adiantamento sobre contratos de câmbio (ACC) -...        1
# 1  Adiantamento sobre contratos de câmbio (ACC) -...        2
# 2  Adiantamento sobre contratos de câmbio (ACC) -...        3
# 3  Adiantamento sobre contratos de câmbio (ACC) -...        4
# 4  Adiantamento sobre contratos de câmbio (ACC) -...        5
#
#          InstituicaoFinanceira  TaxaJurosAoMes  TaxaJurosAoAno     cnpj8
# ...

# %%
import sqlite3

con = sqlite3.connect("src/datasets/taxa_juros.db")
cursor = con.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print(tables)
con.close()
# Out:
# [('taxa_juros',)]

# %%
# Mostrar as primeiras linhas do DataFrame
df.head()
# Out:
#   InicioPeriodo FimPeriodo codigoSegmento         Segmento codigoModalidade  \
# 0    2025-05-19 2025-05-23              2  Pessoa Jurídica           502205
# 1    2025-05-19 2025-05-23              2  Pessoa Jurídica           502205
# 2    2025-05-19 2025-05-23              2  Pessoa Jurídica           502205
# 3    2025-05-19 2025-05-23              2  Pessoa Jurídica           502205
# 4    2025-05-19 2025-05-23              2  Pessoa Jurídica           502205
#
#                                           Modalidade  Posicao  \
# 0  Adiantamento sobre contratos de câmbio (ACC) -...        1
# 1  Adiantamento sobre contratos de câmbio (ACC) -...        2
# 2  Adiantamento sobre contratos de câmbio (ACC) -...        3
# 3  Adiantamento sobre contratos de câmbio (ACC) -...        4
# 4  Adiantamento sobre contratos de câmbio (ACC) -...        5
#
#          InstituicaoFinanceira  TaxaJurosAoMes  TaxaJurosAoAno     cnpj8
# ...

# %%
# Célula 4: Converter colunas de datas para datetime
for col in ['InicioPeriodo', 'FimPeriodo']:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
# Informações gerais do DataFrame e tipos de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   InicioPeriodo          10000 non-null  datetime64[ns]
#  1   FimPeriodo             10000 non-null  datetime64[ns]
#  2   codigoSegmento         10000 non-null  object
#  3   Segmento               10000 non-null  object
#  4   codigoModalidade       10000 non-null  object
#  5   Modalidade             10000 non-null  object
#  6   Posicao                10000 non-null  int64
#  7   InstituicaoFinanceira  10000 non-null  object
#  8   TaxaJurosAoMes         10000 non-null  float64
#  9   TaxaJurosAoAno         10000 non-null  float64
#  10  cnpj8                  10000 non-null  object
# dtypes: datetime64[ns](2), float64(2), int64(1), object(6)
# memory usage: 859.5+ KB

# %%
# Estatísticas descritivas básicas das colunas numéricas
df[['TaxaJurosAoMes', 'TaxaJurosAoAno']].describe()
# Out:
#        TaxaJurosAoMes  TaxaJurosAoAno
# count    10000.000000    10000.000000
# mean         4.743769      105.736767
# std          4.712019      163.344035
# min          0.000000        0.000000
# 25%          1.770000       23.410000
# 50%          2.520000       34.820000
# 75%          6.142500      104.500000
# max         22.070000      994.610000

# %%
#Cálculo de média, variância e desvio padrão das taxas de juros
mean_mes = df['TaxaJurosAoMes'].mean()
var_mes = df['TaxaJurosAoMes'].var()
std_mes = df['TaxaJurosAoMes'].std()

mean_ano = df['TaxaJurosAoAno'].mean()
var_ano = df['TaxaJurosAoAno'].var()
std_ano = df['TaxaJurosAoAno'].std()

print(f"Taxa de Juros ao Mês: Média={mean_mes:.2f}%, Variância={var_mes:.4f}, Desvio Padrão={std_mes:.2f}")
print(f"Taxa de Juros ao Ano: Média={mean_ano:.2f}%, Variância={var_ano:.4f}, Desvio Padrão={std_ano:.2f}")
# Out:
# Taxa de Juros ao Mês: Média=4.74%, Variância=22.2031, Desvio Padrão=4.71
# Taxa de Juros ao Ano: Média=105.74%, Variância=26681.2737, Desvio Padrão=163.34

# %%
# Contagem das modalidades mais frequentes
df['Modalidade'].value_counts().head(10)
# Out:
# Modalidade
# Crédito pessoal não-consignado - Pré-fixado                   1068
# Cartão de crédito - rotativo total - Pré-fixado                753
# Cartão de crédito - parcelado - Pré-fixado                     745
# Desconto de duplicatas - Pré-fixado                            713
# Cheque especial - Pré-fixado                                   710
# Capital de giro com prazo superior a 365 dias - Pré-fixado     626
# Crédito pessoal consignado privado - Pré-fixado                579
# Aquisição de veículos - Pré-fixado                             578
# Crédito pessoal consignado público - Pré-fixado                564
# Capital de giro com prazo até 365 dias - Pré-fixado            564
# Name: count, dtype: int64

# %%
# Célula 9: Filtrar dados só para 'Pessoa Jurídica' ( Quantidade de linhas que contém somente os dados de segnmento Pessoa jurídica)
df_pj = df[df['Segmento'] == 'Pessoa Jurídica']
print(f"Número de registros para Pessoa Jurídica: {len(df_pj)}")
# Out:
# Número de registros para Pessoa Jurídica: 4347

# %%
#Estatísticas descritivas para Pessoa Jurídica (Taxas de Juros)
df_pj[['TaxaJurosAoMes', 'TaxaJurosAoAno']].describe()
# Out:
#        TaxaJurosAoMes  TaxaJurosAoAno
# count     4347.000000     4347.000000
# mean         2.998328       53.549505
# std          3.051020       84.509691
# min          0.000000        0.000000
# 25%          1.430000       18.550000
# 50%          2.000000       26.860000
# 75%          3.055000       43.500000
# max         20.430000      831.160000

# %%
# variância e desvio padrão para Pessoa Jurídica
mean_mes_pj = df_pj['TaxaJurosAoMes'].mean()
var_mes_pj = df_pj['TaxaJurosAoMes'].var()
std_mes_pj = df_pj['TaxaJurosAoMes'].std()

mean_ano_pj = df_pj['TaxaJurosAoAno'].mean()
var_ano_pj = df_pj['TaxaJurosAoAno'].var()
std_ano_pj = df_pj['TaxaJurosAoAno'].std()

print(f"[Pessoa Jurídica] Taxa de Juros ao Mês: Média={mean_mes_pj:.2f}%, Variância={var_mes_pj:.4f}, Desvio Padrão={std_mes_pj:.2f}")
print(f"[Pessoa Jurídica] Taxa de Juros ao Ano: Média={mean_ano_pj:.2f}%, Variância={var_ano_pj:.4f}, Desvio Padrão={std_ano_pj:.2f}")
# Out:
# [Pessoa Jurídica] Taxa de Juros ao Mês: Média=3.00%, Variância=9.3087, Desvio Padrão=3.05
# [Pessoa Jurídica] Taxa de Juros ao Ano: Média=53.55%, Variância=7141.8879, Desvio Padrão=84.51

# %% [markdown]
# Vendo se tem dados faltantes

# %%
df.isnull().sum()
# Out:
# InicioPeriodo            0
# FimPeriodo               0
# codigoSegmento           0
# Segmento                 0
# codigoModalidade         0
# Modalidade               0
# Posicao                  0
# InstituicaoFinanceira    0
# TaxaJurosAoMes           0
# TaxaJurosAoAno           0
# cnpj8                    0
# dtype: int64

# %%
df
# Out:
#      InicioPeriodo  FimPeriodo codigoSegmento         Segmento  \
# 0       2025-05-19  2025-05-23              2  Pessoa Jurídica
# 1       2025-05-19  2025-05-23              2  Pessoa Jurídica
# 2       2025-05-19  2025-05-23              2  Pessoa Jurídica
# 3       2025-05-19  2025-05-23              2  Pessoa Jurídica
# 4       2025-05-19  2025-05-23              2  Pessoa Jurídica
# ...            ...         ...            ...              ...
# 9995    2025-04-29  2025-05-06              1    Pessoa Física
# 9996    2025-04-29  2025-05-06              1    Pessoa Física
# 9997    2025-04-29  2025-05-06              1    Pessoa Física
# 9998    2025-04-29  2025-05-06              1    Pessoa Física
# 9999    2025-04-29  2025-05-06              1    Pessoa Física
#
#      codigoModalidade                                         Modalidade  \
# 0              502205  Adiantamento sobre contratos de câmbio (ACC) -...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# %% [markdown]
# ## Quais modalidades de crédito têm as maiores médias de taxa de juros anuais entre pessoas jurídicas.

# %%
pj_modalidade_taxa = df_pj.groupby('Modalidade')['TaxaJurosAoAno'].mean().sort_values(ascending=False)
pj_modalidade_taxa.head(10)
# Out:
# Modalidade
# Cheque especial - Pré-fixado                                                                   232.965350
# Conta garantida - Pré-fixado                                                                    84.446573
# Capital de giro com prazo até 365 dias - Pré-fixado                                             63.156472
# Desconto de cheques - Pré-fixado                                                                44.672568
# Capital de giro com prazo superior a 365 dias - Pré-fixado                                      33.869888
# Desconto de duplicatas - Pré-fixado                                                             33.518682
# Conta garantida - Pós-fixado referenciado em juros flutuantes                                   29.967365
# Vendor - Pré-fixado                                                                             25.947184
# Capital de giro com prazo até 365 dias - Pós-fixado referenciado em juros flutuantes            22.172785
# ...

# %% [markdown]
# ## Estudo por gráficos
#
# para complementar o processo de análise de dados vamos gerar alguns gráficos, para isso usaremos a biblioteca matplotlib.

# %% [markdown]
# ## Histograma das taxas de juros ao mês (todas as modalidades)

# %%
plt.hist(df['TaxaJurosAoMes'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histograma da Taxa de Juros ao Mês (todas modalidades)')
plt.xlabel('Taxa de Juros ao Mês (%)')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ## Boxplot das taxas de juros ao ano agrupadas por modalidade (top 10 modalidades)

# %%
top_modalidades = df['Modalidade'].value_counts().head(10).index
df_top_modalidades = df[df['Modalidade'].isin(top_modalidades)]

plt.figure(figsize=(14,7))
sns.boxplot(x='TaxaJurosAoAno', y='Modalidade', data=df_top_modalidades, palette='Set3')
plt.title('Boxplot da Taxa de Juros ao Ano para as 10 Modalidades mais comuns')
plt.xlabel('Taxa de Juros ao Ano (%)')
plt.ylabel('Modalidade')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11756\2034260953.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='TaxaJurosAoAno', y='Modalidade', data=df_top_modalidades, palette='Set3')

# %% [markdown]
# ## Série temporal da taxa média mensal ao longo do tempo para Pessoa Jurídica

# %%
df_time_pj = df_pj.groupby('InicioPeriodo')['TaxaJurosAoMes'].mean()

plt.figure(figsize=(14,6))
df_time_pj.plot()
plt.title('Evolução da Taxa Média Mensal ao Longo do Tempo (Pessoa Jurídica)')
plt.xlabel('Data de Início do Período')
plt.ylabel('Taxa Média Mensal (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Gráfico da média da taxa anual por modalidade para Pessoa Jurídica (top 10)

# %%
plt.figure(figsize=(12,6))
pj_modalidade_taxa.head(10).plot(kind='bar', color='coral')
plt.title('Média da Taxa Anual por Modalidade (Pessoa Jurídica) - Top 10')
plt.ylabel('Taxa Média Anual (%)')
plt.xlabel('Modalidade')
plt.xticks(rotation=45, ha='right')
plt.show()
