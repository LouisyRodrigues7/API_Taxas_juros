# %%
# Análise Estatística - Taxa de Juros

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carrega os dados
df = pd.read_csv('src/datasets/taxaJuros.csv', sep=';', decimal='.')
df['InicioPeriodo'] = pd.to_datetime(df['InicioPeriodo'], errors='coerce')

# %% [markdown]
# ---
#
# ## Análise descritiva

# %%
# Análise descritiva
print("📌 Tipos de dados:")
print(df.dtypes)
# Out:
# 📌 Tipos de dados:
# InicioPeriodo            datetime64[ns]
# FimPeriodo                       object
# codigoSegmento                    int64
# Segmento                         object
# codigoModalidade                  int64
# Modalidade                       object
# Posicao                           int64
# InstituicaoFinanceira            object
# TaxaJurosAoMes                  float64
# TaxaJurosAoAno                  float64
# cnpj8                             int64
# dtype: object

# %%
df.head(10).style.set_caption("📋 Primeiras 25 Linhas") \
    .background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_80926_row0_col2, #T_80926_row0_col4, #T_80926_row0_col6, #T_80926_row0_col8, #T_80926_row0_col9, #T_80926_row1_col2, #T_80926_row1_col4, #T_80926_row2_col2, #T_80926_row2_col4, #T_80926_row2_col10, #T_80926_row3_col2, #T_80926_row3_col4, #T_80926_row4_col2, #T_80926_row4_col4, #T_80926_row5_col2, #T_80926_row5_col4, #T_80926_row6_col2, #T_80926_row6_col4, #T_80926_row7_col2, #T_80926_row7_col4, #T_80926_row8_col2, #T_80926_row8_col4, #T_80926_row9_col2, #T_80926_row9_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_80926_row0_col10, #T_80926_row3_col10, #T_80926_row6_col10 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_80926_row1_col6 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_80926_row1_col8, #T_80926_row2_col8 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_80926_row1_col9 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_80926_row1_col10 {
#   background-color: #f4f9fe;
# ...

# %%
estatisticas = df.describe(include='all').T
estatisticas.style.set_caption("📊 Estatísticas Descritivas das Colunas") \
    .format(precision=2) \
    .background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# </style>
# <table id="T_9e983">
#   <caption>📊 Estatísticas Descritivas das Colunas</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e983_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_9e983_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_9e983_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_9e983_level0_col3" class="col_heading level0 col3" >freq</th>
#       <th id="T_9e983_level0_col4" class="col_heading level0 col4" >mean</th>
#       <th id="T_9e983_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_9e983_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_9e983_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_9e983_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_9e983_level0_col9" class="col_heading level0 col9" >max</th>
# ...
